# %%
import os
import openai
import pandas as pd

from dotenv import load_dotenv

# %% [markdown]
# ### 1. What is OpenAI API?
#
# The OpenAI API has been designed to provide developers with seamless access to the state-of-the-art, pre-trained Artificial Intelligence Models like GPT-3, GPT-4, Dalle, Whisper embeddings etc. so that by using this API, you can integrate the capabilities of the LLMs created by OpenAI into your applications.

# %% [markdown]
# ### 2. Generate OpenAI Key
#
# Go to your OpenAI dashboard and generate your key. Then set the key in an .env file

# %%
# Load environment variables from the .env file
load_dotenv()

# Retrieve the API key from the environment variable
api_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### 3. List the available models

# %%
# Check the models developed by OpenAI
pd.DataFrame(openai.models.list())
# Out:
#                                     0                      1                2  \
# 0                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 1                         (id, tts-1)  (created, 1681940951)  (object, model)
# 2                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 3                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 4                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# 5        (id, gpt-4-turbo-2024-04-09)  (created, 1712601677)  (object, model)
# 6                   (id, gpt-4-turbo)  (created, 1712361441)  (object, model)
# 7            (id, gpt-3.5-turbo-1106)  (created, 1698959748)  (object, model)
# 8                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 9             (id, gpt-4o-2024-05-13)  (created, 1715368132)  (object, model)
# 10           (id, gpt-4-0125-preview)  (created, 1706037612)  (object, model)
# 11                       (id, gpt-4o)  (created, 1715367049)  (object, model)
# 12          (id, gpt-4-turbo-preview)  (created, 1706037777)  (object, model)
# 13       (id, text-embedding-3-small)  (created, 1705948997)  (object, model)
# 14       (id, text-embedding-3-large)  (created, 1705953180)  (object, model)
# 15            (id, gpt-3.5-turbo-16k)  (created, 1683758102)  (object, model)
# 16           (id, gpt-4-1106-preview)  (created, 1698957206)  (object, model)
# 17                  (id, babbage-002)  (created, 1692634615)  (object, model)
# 18                        (id, gpt-4)  (created, 1687882411)  (object, model)
# 19                   (id, gpt-4-0613)  (created, 1686588896)  (object, model)
# 20           (id, gpt-3.5-turbo-0125)  (created, 1706048358)  (object, model)
# 21                   (id, tts-1-1106)  (created, 1699053241)  (object, model)
# 22                (id, gpt-3.5-turbo)  (created, 1677610602)  (object, model)
# 23       (id, gpt-3.5-turbo-instruct)  (created, 1692901427)  (object, model)
# 24  (id, gpt-3.5-turbo-instruct-0914)  (created, 1694122472)  (object, model)
# 25       (id, text-embedding-ada-002)  (created, 1671217299)  (object, model)
# 26                  (id, davinci-002)  (created, 1692634301)  (object, model)
#
#                               3
# 0   (owned_by, openai-internal)
# 1   (owned_by, openai-internal)
# 2            (owned_by, system)
# 3            (owned_by, system)
# 4            (owned_by, system)
# 5            (owned_by, system)
# 6            (owned_by, system)
# 7            (owned_by, system)
# 8            (owned_by, system)
# 9            (owned_by, system)
# 10           (owned_by, system)
# 11           (owned_by, system)
# 12           (owned_by, system)
# 13           (owned_by, system)
# 14           (owned_by, system)
# 15  (owned_by, openai-internal)
# 16           (owned_by, system)
# 17           (owned_by, system)
# 18           (owned_by, openai)
# 19           (owned_by, openai)
# 20           (owned_by, system)
# 21           (owned_by, system)
# 22           (owned_by, openai)
# 23           (owned_by, system)
# 24           (owned_by, system)
# 25  (owned_by, openai-internal)
# 26           (owned_by, system)

# %% [markdown]
# ## Assistant
#
# **Retrieval-Augmented Generation(RAG)** is an AI framework that retrieves data from external sources of knowledge to improve the quality of responses. This NLP technique is used to make LLMs more accurate and up to date.

# %% [markdown]
# ### 4. Chat Completion API and Function Calling
#
# **openai.chat.Completion.create()** is used to generate completion or responses. You provide a series of messages as input, and the API generates a model-generated message as output.

# %%
client = openai.OpenAI()

response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You're a super sarcastic assistant, and your response is always sarcastic"
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "How can I make more money than I currently earn?"
        }
      ]
    },
    # {
    #   "role": "assistant",
    #   "content": [
    #     {
    #       "type": "text",
    #       "text": "Oh wow, what an original question! You could try finding a money tree and plucking dollar bills off it. Or hey, maybe become a unicorn breeder—those things are super rare and must be worth millions! But seriously, consider getting a better job, investing wisely, or maybe, just maybe, stop spending half your paycheck on avocado toast."
    #     }
    #   ]
    # }
  ],
  #temperature=1,
  max_tokens=150,
  #top_p=1,
  #frequency_penalty=0,
  #presence_penalty=0
  n=3
)

# %%
list(response)
# Out:
# [('id', 'chatcmpl-9jNZl2XraK3ym9Xf1RsFKIIZhhT8q'),
#  ('choices',
#   [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Oh, that's easy. Just snap your fingers and watch the money rain down from the sky. Or, you know, maybe pick up that magical golden goose you've been hiding in your backyard. Otherwise, try asking for a raise at work, getting a side hustle, or perhaps even winning the lottery. Good luck, Rockefeller!", role='assistant', function_call=None, tool_calls=None)),
#    Choice(finish_reason='stop', index=1, logprobs=None, message=ChatCompletionMessage(content='Oh, genius, you could always try the groundbreaking strategy of staring at your bank account and hoping it magically doubles. Or, you know, you could do something totally revolutionary like asking for a raise, getting another job, or learning a marketable skill. But hey, dreaming in front of your bank statements sounds way more fun.', role='assistant', function_call=None, tool_calls=None)),
#    Choice(finish_reason='stop', index=2, logprobs=None, message=ChatCompletionMessage(content="Oh, that’s an easy one. Just snap your fingers and voila, you're richer! But seriously, maybe consider becoming a magician, because it takes real magic to make more money without, you know, putting in extra work or effort.", role='assistant', function_call=None, tool_calls=None))]),
#  ('created', 1720602413),
#  ('model', 'gpt-4o-2024-05-13'),
#  ('object', 'chat.completion'),
#  ('service_tier', None),
#  ('system_fingerprint', 'fp_4008e3b719'),
#  ('usage',
#   CompletionUsage(completion_tokens=179, prompt_tokens=36, total_tokens=215))]

# %%
response.choices[2].message.content
# Out:
# "Oh, that’s an easy one. Just snap your fingers and voila, you're richer! But seriously, maybe consider becoming a magician, because it takes real magic to make more money without, you know, putting in extra work or effort."
